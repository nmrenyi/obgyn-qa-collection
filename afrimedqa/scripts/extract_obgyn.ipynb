# %%
import pandas as pd

# %%
df = pd.read_csv("../sources/afri_med_qa_15k_v2.4_phase_2_15275.csv")
df.info()

# %%
df['discipline'].value_counts()
# Out:
# discipline
# Medicine                    6986
# Non-Health                  1952
# Health Research             1036
# Other Health Professions     900
# Nursing                      831
# Pharmacy                     772
# Laboratory Sciences          350
# Name: count, dtype: int64

# %%
df['specialty'].value_counts()
# Out:
# specialty
# Obstetrics_and_Gynecology               824
# General_Surgery                         757
# Pediatrics                              747
# Pathology                               381
# Infectious_Disease                      321
# Neurology                               310
# Psychiatry                              299
# Cardiology                              258
# Internal_Medicine                       238
# Endocrinology                           236
# Pulmonary_Medicine                      231
# Gastroenterology                        225
# Allergy_and_Immunology                  217
# Hematology                              211
# Ophthalmology                           202
# Obstetric                               184
# Rheumatology                            171
# General                                 169
# Nephrology                              163
# Orthopedic_Surgery                      161
# Otolaryngology                          158
# Oncology                                135
# Urology                                 134
# Plastic_Surgery                         132
# Dermatology                             126
# Other                                   125
# Emergency_Medicine                      123
# Family_Medicine                         120
# Anesthesiology                          115
# Neurosurgery                            107
# Radiology                               107
# Physical_Medicine_and_Rehabilitation    101
# Pandemic                                 92
# Geriatrics                               91
# Medical_Genetics                         86
# Communicable_Disease                     72
# Hemorrhagic_Fevers                       54
# Name: count, dtype: int64

# %%
cols = [
    "question_type",
    "tier",
    # "split",
    "prompt",
    "question_clean",
    "answer_options",
    "correct_answer",
    "answer_rationale",
]

# %%
df['question_type'].value_counts()
# Out:
# question_type
# consumer_queries    10000
# mcq                  4039
# saq                  1236
# Name: count, dtype: int64

# %%
# rows with specialty Obstetric
obgyn = df[
    (df["specialty"].str.contains("Obstetric", case=False, na=False)) 
    & (df["question_type"].isin(["mcq", "saq"]))
    & (df["tier"] == "expert")
][cols].reset_index(drop=True)

# %%
obgyn
# Out:
#     question_type    tier prompt  \
# 0             mcq  expert    NaN
# 1             mcq  expert    NaN
# 2             mcq  expert    NaN
# 3             mcq  expert    NaN
# 4             mcq  expert    NaN
# ..            ...     ...    ...
# 692           mcq  expert    NaN
# 693           mcq  expert    NaN
# 694           mcq  expert    NaN
# 695           mcq  expert    NaN
# 696           mcq  expert    NaN
#
#                                         question_clean  \
# 0    56 years old woman has come to you with the co...
# 1    A newly married girl comes to gynae OPD with h...
# 2    28 years old woman with previous history of ha...
# 3    A 20-year-old medical student presents with fi...
# 4    A large cystic ovarian tumour is detected in a...
# ..                                                 ...
# 692  Which of the following Is not a screening meth...
# 693  which of these does not define antenatal cardi...
# 694  Which of the following best describes the use ...
# 695  Elective cervical cerclage is indicated in whi...
# 696  This is not a part of Biophysical profile\r\n\r\n
#
#                                         answer_options correct_answer  \
# 0    {"option1": "Hysterectomy.", "option2": "Vitam...        option3
# 1    {"option1": "Trichomonas vaginalis.", "option2...        option4
# 2    {"option1": "Obstetric ultrasound.", "option2"...        option2
# 3    {"option1": "Polycystic ovarian disease.", "op...        option1
# 4    {"option1": "Torsion.", "option2": "Rupture. ....        option1
# ..                                                 ...            ...
# 692  {"option1": "HbA1C", "option2": "Fasting Blood...        option3
# 693  {"option1": "a normal baseline should be 120-1...        option4
# 694  {"option1": "should be used for instrumental d...        option3
# 695  {"option1": "Three spontaneous first \u2013 tr...        option3
# 696  {"option1": "Amniotic fluid volume", "option2"...        option3
#
#     answer_rationale
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 692              NaN
# 693              NaN
# 694              NaN
# 695              NaN
# 696              NaN
#
# [697 rows x 7 columns]

# %%
obgyn.head(5).to_records()
# Out:
# rec.array([(0, 'mcq', 'expert', nan, '56 years old woman has come to you with the complaints of hot flushes irritability, joint pains with lack of sleep. Most appropriate treatment would be: \r\n', '{"option1": "Hysterectomy.", "option2": "Vitamins.", "option3": "Combined oestrogen, progesterone preparations.", "option4": "Phytooestrogens.", "option5": "Selective estrogen receptor modulators (SERMS)."}', 'option3', nan),
#            (1, 'mcq', 'expert', nan, 'A newly married girl comes to gynae OPD with history of dysuria, burning, micturition and sore perineum. What is your likely diagnosis: \r\n', '{"option1": "Trichomonas vaginalis.", "option2": "Candida infection.", "option3": "Trauma due to coitus.", "option4": "Honey moon cystitis.", "option5": "Genital herpes."}', 'option4', nan),
#            (2, 'mcq', 'expert', nan, "28 years old woman with previous history of having baby with Down's \r\nSyndrome is now 12 weeks pregnant. Which of the following would you suggest to her: \r\nAmniocentesis. \r\n", '{"option1": "Obstetric ultrasound.", "option2": "Chorionic villus sampling.", "option3": "Fetal blood sampling.", "option4": "Wait till eighteen weeks for detailed ultrasound and amniocentesis.", "option5": "Obstetric ultrasound."}', 'option2', nan),
#            (3, 'mcq', 'expert', nan, 'A 20-year-old medical student presents with five years history of weight gain, irregular periods and worsening fascial hair. What is the most likely diagnosis? \r\n', '{"option1": "Polycystic ovarian disease.", "option2": "Hypothyroidism.", "option3": "Obesity.", "option4": "Cushing\'s Syndrome.", "option5": "Nephrotic Syndrome."}', 'option1', nan),
#            (4, 'mcq', 'expert', nan, 'A large cystic ovarian tumour is detected in a woman on routine antenatal check-up. The most common complication she can encounter is: \r\n', '{"option1": "Torsion.", "option2": "Rupture. .", "option3": "Haemorrhage", "option4": "Degeneration.", "option5": "Infection."}', 'option1', nan)],
#           dtype=[('index', '<i8'), ('question_type', 'O'), ('tier', 'O'), ('prompt', 'O'), ('question_clean', 'O'), ('answer_options', 'O'), ('correct_answer', 'O'), ('answer_rationale', 'O')])

# %%
# remove the newline characters in the question_clean columns, \n, \r, and then strip leading and trailing whitespace
obgyn['question_clean'] = obgyn['question_clean'].str.replace('\n', ' ', regex=False).str.replace('\r', ' ', regex=False).str.strip()

# %%
obgyn[obgyn['question_type'] == 'saq'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 499 to 535
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   question_type     37 non-null     object
#  1   tier              37 non-null     object
#  2   prompt            0 non-null      object
#  3   question_clean    37 non-null     object
#  4   answer_options    0 non-null      object
#  5   correct_answer    0 non-null      object
#  6   answer_rationale  37 non-null     object
# dtypes: object(7)
# memory usage: 2.3+ KB

# %%
saq = obgyn[obgyn['question_type'] == 'saq'][['question_clean', 'answer_rationale']].copy()
saq['answer_rationale'] = saq['answer_rationale'].str.replace('\n', ' ', regex=False).str.replace('\r', ' ', regex=False).str.strip()
saq.to_csv("../data/obgyn_saq.tsv", sep="\t", index=False)
saq.head(3)

# %%
import json

def parse_options(row):
    opts = json.loads(row['answer_options'])
    letters = {f'option{i}': chr(64+i) for i in range(1, 6)}  # option1→A, option2→B, ...

    # Format options on a single line: "A. Hysterectomy | B. Vitamins | ..."
    formatted = " | ".join(f"{letters[k]}. {v}" for k, v in opts.items())

    # Handle multiple correct answers: "option1,option3" → "A,C"
    answer_letters = ",".join(letters[o.strip()] for o in row['correct_answer'].split(","))

    return formatted, answer_letters

mcq = obgyn[obgyn['question_type'] == 'mcq'].copy()
mcq[['options_formatted', 'correct_letter']] = mcq.apply(parse_options, axis=1, result_type='expand')

mcq[['question_clean', 'options_formatted', 'correct_letter']].to_csv("../data/obgyn_mcq.tsv", sep="\t", index=False)
mcq[['question_clean', 'options_formatted', 'correct_letter']].head(3)
